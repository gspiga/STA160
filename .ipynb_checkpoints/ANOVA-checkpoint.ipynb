# %% [markdown]
# # ANOVA with Gender and Age Groups

# %%
import numpy as np
import pandas as pd
import plotly.express as px
from IPython.display import display

# %%
data = pd.read_csv("Data/data_clean.csv", index_col = [0])

#Creating Age Groups
data.loc[(data['age'] > 14) & (data['age'] <= 24), 'Age Group'] = 'Youth (15-24)'
data.loc[(data['age'] > 25) & (data['age'] <= 64), 'Age Group'] = 'Adults (25-64)'
data.loc[(data['age'] >= 65), 'Age Group'] = 'Seniors (65+)'

# Making Gender Categorical
data["gender"].replace({1:"Male", 2: "Female", 3: "Other"}, inplace = True)
display(data)
# Out:
#        score  Influence  Modesty  Daring  Confidence  Ruling  Responsibility  \
# 0         18          2        2       2           2       1               2
# 1          6          2        2       2           1       2               2
# 2         27          1        2       2           1       2               1
# 3         29          1        1       2           2       2               1
# 4          6          1        2       1           1       1               2
# ...      ...        ...      ...     ...         ...     ...             ...
# 11238      1          2        2       2           1       1               2
# 11239     10          2        2       1           1       1               2
# 11240      6          1        2       2           1       1               2
# 11241     12          2        2       1           1       1               1
# 11242     18          1        2       1           1       1               1
#
# ...

# %%
display(px.box(data, x = 'Age Group', y = 'score', color = 'gender'))
pd.crosstab(data["score"], data["Age Group"])
# Out:
# <div>                            <div id="2d7b5e87-7c5b-4358-9e92-83faa179c2ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d7b5e87-7c5b-4358-9e92-83faa179c2ea")) {                    Plotly.newPlot(                        "2d7b5e87-7c5b-4358-9e92-83faa179c2ea",                        [{"alignmentgroup":"True","hovertemplate":"gender=Male<br>Age Group=%{x}<br>score=%{y}<extra></extra>","legendgroup":"Male","marker":{"color":"#636efa"},"name":"Male","notched":false,"offsetgroup":"Male","orientation":"v","showlegend":true,"x":["Adults (25-64)","Adults (25-64)","Adults (25-64)","Adults (25-64)","Adults (25-64)","Adults (25-64)","Adults (25-64)",null,"Adults (25-64)","Adults (25-64)","Adults (25-64)","Adults (25-64)","Adults (25-64)","Adults (25-64
# ...
